# %%
println("D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)   ")
println(" ")
println("#λh,")
println("#EPSD=5*10^-4,")
@time begin
    v1 =μ1(0.001, 0.001, 0.580) 
end 
println("#EPSD=5*10^-14,")
@time begin
    v2 =μ2(0.001, 0.001, 0.580) 
end 
println("#EPSD=5*10^-16,")
@time begin
    v3 =μ3(0.001, 0.001, 0.580) 
end
println(" ")
println("#λwj,")
println("#EPSD=5*10^-4,")
@time begin
    v4 =μ4(0.001, 0.001, 0.580) 
end 
println("#EPSD=5*10^-14,")
@time begin
    v5 =μ5(0.001, 0.001, 0.580) 
end 
println("#EPSD=5*10^-16,")
@time begin
    v6 =μ6(0.001, 0.001, 0.580) 
end 
println(" ")
println("#λmd,")
println("#EPSD=5*10^-4,")
@time begin
    v7 =μ7(0.001, 0.001, 0.580) 
end 
println("#EPSD=5*10^-14,")
@time begin
    v8 =μ8(0.001, 0.001, 0.580) 
end 
println("#EPSD=5*10^-16,")
@time begin
    v9 =μ9(0.001, 0.001, 0.580) 
end
# Out:
# D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)
#
# #λh,
# #EPSD=5*10^-4,
# 174.400431 seconds (128.20 M allocations: 4.145 GiB, 0.36% gc time)
# #EPSD=5*10^-14,
# 174.534697 seconds (128.33 M allocations: 4.147 GiB, 0.36% gc time)
# #EPSD=5*10^-16,
# 173.930466 seconds (128.33 M allocations: 4.147 GiB, 0.36% gc time)
#
# #λwj,
# #EPSD=5*10^-4,
# 174.731504 seconds (128.40 M allocations: 4.149 GiB, 0.36% gc time)
# #EPSD=5*10^-14,
# 174.893425 seconds (128.59 M allocations: 4.152 GiB, 0.36% gc time)
# #EPSD=5*10^-16,
# 174.420206 seconds (128.59 M allocations: 4.152 GiB, 0.36% gc time)
#
# #λmd,
# #EPSD=5*10^-4,
#  92.806539 seconds (87.20 M allocations: 3.356 GiB, 0.51% gc time)
# #EPSD=5*10^-14,
# 127.755953 seconds (98.45 M allocations: 3.524 GiB, 0.40% gc time)
# #EPSD=5*10^-16,
# 127.001809 seconds (98.45 M allocations: 3.524 GiB, 0.41% gc time)
# 21442340

# %%
@time begin
    v =μ(0.001, 0.001, 0.580) 
end
# Out:
#  42.575480 seconds (85.79 M allocations: 3.516 GiB, 0.90% gc time)
# 21442340

# %%
D1=Newton_Raphson_Classic(Bo, B1, B2, B3, B4, λoD, epsd)    
D2=Newton_Raphson_WJ_with_RF(μ, Ct, αdr, λoD, epsd)     
D3=Newton_Raphson_WJ_without_RF(μ, Ct, αdr, λoD, epsd)    
D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)
# Out:
# UndefVarError: Bo not defined
#
# Stacktrace:
#  [1] top-level scope at In[26]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
function Speed_Test(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-4
αdr=αd*pi/180 # αd transform in radians  
λoD=λh
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)   

D1=Newton_Raphson_Classic(Bo, B1, B2, B3, B4, λoD, epsd)     
end
# Out:
# Speed_Test (generic function with 1 method)

# %%
function Speed_Test_λh_04(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-4
αdr=αd*pi/180 # αd transform in radians  
λoD=λh
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)   

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)   
end
# Out:
# Speed_Test_λh_04 (generic function with 1 method)

# %%
function Speed_Test_λh_14(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-14
αdr=αd*pi/180 # αd transform in radians  
λoD=λh
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)  

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)
end
# Out:
# Speed_Test_λh_14 (generic function with 1 method)

# %%
function Speed_Test_λh_16(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-16
αdr=αd*pi/180 # αd transform in radians  
λoD=λh
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4) 
    
D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)  
end
# Out:
# Speed_Test_λh_16 (generic function with 1 method)

# %%
function Speed_Test_λwj_04(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-4
αdr=αd*pi/180 # αd transform in radians  
λoD=λwj
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)  

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)     
end
# Out:
# Speed_Test_λwj_04 (generic function with 1 method)

# %%
function Speed_Test_λwj_14(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-14
αdr=αd*pi/180 # αd transform in radians  
λoD=λwj
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)       
end
# Out:
# Speed_Test_λwj_14 (generic function with 1 method)

# %%
function Speed_Test_λwj_16(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-16
αdr=αd*pi/180 # αd transform in radians  
λoD=λwj
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)      
end
# Out:
# Speed_Test_λwj_16 (generic function with 1 method)

# %%
function Speed_Test_λmd_04(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-4
αdr=αd*pi/180 # αd transform in radians  
λoD=λmd
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4) 

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd) 
end
# Out:
# Speed_Test_λmd_04 (generic function with 1 method)

# %%
function Speed_Test_λmd_14(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-14
αdr=αd*pi/180 # αd transform in radians  
λoD=λmd
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4) 

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)     
end
# Out:
# Speed_Test_λmd_14 (generic function with 1 method)

# %%
function Speed_Test_λmd_16(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
epsd=5*10^-16
αdr=αd*pi/180 # αd transform in radians  
λoD=λmd
Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)

D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)        
end
# Out:
# Speed_Test_λmd_16 (generic function with 1 method)

# %%
function μ1(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λh_04(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ1 (generic function with 1 method)

# %%
function μ2(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λh_14(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ2 (generic function with 1 method)

# %%
function μ3(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λh_16(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ3 (generic function with 1 method)

# %%
function μ4(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λwj_04(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ4 (generic function with 1 method)

# %%
function μ5(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λwj_14(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ5 (generic function with 1 method)

# %%
function μ6(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λwj_16(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ6 (generic function with 1 method)

# %%
function μ7(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λmd_04(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ7 (generic function with 1 method)

# %%
function μ8(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λmd_14(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ8 (generic function with 1 method)

# %%
function μ9(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test_λmd_16(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ9 (generic function with 1 method)

# %%
function μ(μmin, dμ, μmax)    
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ (generic function with 1 method)

# %%
function Newton_Raphson_Classic(Bo, B1, B2, B3, B4, λo, epsd)
    
         EPS=epsd
         LoPo=0
         ITNumb=0
         Jack=0
         
    ####################################################
    #                                                ###
    # THE METHOD FIRST PART                          ###     
         
         λo=λo                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3       
         u=f/fprime                                  
         w=λo-u                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER FIRST             ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1                     ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
         λ=w                              ##############
         eps=abs((λ-λo)/λ)                ##############
         Eps=eps                          ##############
         ITNumb=ITNumb+1                  ##############
            end                           ##############
                                          ##############
  ######################################################
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################
  ######################################################
  # #                                                ###
  # # THE METHOD FINAL PART                          ###     
  # #                                                ###                                       
         λo=λ
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3       
         u=f/fprime                                  
         w=λo-u                                      
  # #                                                ###
  ######################################################
  # #                               ####################
  # # THE CHECKER SECOND            ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################          
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER FINAL                 ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
            else                          ##############  
         λ=w                              ##############
         eps=abs((λ-λo)/λ)                ##############
         Eps=eps                          ##############       
         ITNumb=ITNumb+1                  ##############
            end                           ############## 
            end                           ##############
        end                               ##############
  # #                                     ##############
  ######################################################
 λD=λ 
if λD<0
println("Alert")
    end
 ITNumbD=ITNumb
 res=[λD, ITNumbD]
 return(res)
 end
# Out:
# Newton_Raphson_Classic (generic function with 1 method)

# %%
function Newton_Raphson_WJ_with_RF(μ, Ct, αdr, λo, epsd)# αd in degrees #####################  

EPS=epsd   
LoPo=0
ITNumb=0
Jack=0
μz=μ*tan(αdr)
λh=sqrt(Ct/2)
f=0.5
    ####################################################
    #                                                ###
    # THE METHOD FIRST PART                          ###     
         λo=λo                                       
         λin=λh^2/sqrt(λo^2+μ^2)                                            
         w=λo-f*(λo-μz-λin)/(1+λin*λo/(λo^2+μ^2))                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER FIRST             ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################                             
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1                     ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
         λ=w                              ##############
         eps=abs((λ-λo)/λ)                ##############
         Eps=eps                          ##############
         ITNumb=ITNumb+1                  ##############
            end                           ##############
                                          ##############
  ######################################################
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################
  ######################################################
 
  ######################################################
  # #                                                ###
  # # THE METHOD FINAL PART                          ###     
  # #                                                ###   
         λo=λ                                       
         λin=λh^2/sqrt(λo^2+μ^2)                                            
         w=λo-f*(λo-μz-λin)/(1+λin*λo/(λo^2+μ^2))                                    
  # #                                                ###
  ######################################################
  # #                               ####################
  # # THE CHECKER SECOND            ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################          
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER FINAL                 ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
            else                          ##############  
         λ=w                              ##############
         eps=abs((λ-λo)/λ)                ##############
         Eps=eps                          ##############       
         ITNumb=ITNumb+1                  ##############
            end                           ############## 
            end                           ##############
        end                               ##############
  # #                                     ##############
  ######################################################
 λD=λ   
 ITNumbD=ITNumb
 res=[λD,ITNumbD]
 return(res)
 end
# Out:
# Newton_Raphson_WJ_with_RF (generic function with 1 method)

# %%
function Newton_Raphson_WJ_without_RF(μ, Ct, αdr, λo, epsd)# αd in degrees #####################  

EPS=epsd
LoPo=0
ITNumb=0
Jack=0
μz=μ*tan(αdr)
λh=sqrt(Ct/2)
f=1
     ####################################################
    #                                                ###
    # THE METHOD FIRST PART                          ###     
         λo=λo                                       
         λin=λh^2/sqrt(λo^2+μ^2)                                            
         w=λo-f*(λo-μz-λin)/(1+λin*λo/(λo^2+μ^2))                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER FIRST             ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################                             
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1                     ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
         λ=w                              ##############
         eps=abs((λ-λo)/λ)                ##############
         Eps=eps                          ##############
         ITNumb=ITNumb+1                  ##############
            end                           ##############
                                          ##############
  ######################################################
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################
  ######################################################
 
  ######################################################
  # #                                                ###
  # # THE METHOD FINAL PART                          ###     
  # #                                                ###   
         λo=λ                                       
         λin=λh^2/sqrt(λo^2+μ^2)                                            
         w=λo-f*(λo-μz-λin)/(1+λin*λo/(λo^2+μ^2))                                    
  # #                                                ###
  ######################################################
  # #                               ####################
  # # THE CHECKER SECOND            ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################          
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER FINAL                 ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
            else                          ##############  
         λ=w                              ##############
         eps=abs((λ-λo)/λ)                ##############
         Eps=eps                          ##############       
         ITNumb=ITNumb+1                  ##############
            end                           ############## 
            end                           ##############
        end                               ##############
  # #                                     ##############
  ######################################################
 λD=λ   
 ITNumbD=ITNumb
 res=[λD,ITNumbD]
 return(res)
 end
# Out:
# Newton_Raphson_WJ_without_RF (generic function with 1 method)

# %%
function Super16_4P16R(Ao, A1, A2, A3, A4, λo, epsd)# αd in degrees #####################   

EPS=epsd    
LoPo=0
ITNumb=0
Jack=0
    
 ###########################################################
    #                                                       ###
    # THE METHOD PART 1.1.                                  ###   
    
         λo=λo                                              
         f=Ao+A1*λo+A2*λo^2+A3*λo^3+A4*λo^4        
         fprime=A1+2*A2*λo+3*A3*λo^2+4*A4*λo^3     
         u=f/fprime                                
         w=λo-u                                    
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.1.              ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Ao+A1*w+A2*w^2+A3*w^3+A4*w^4
         z=λo-u*((f-fw)/(f-2*fw))                              
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.25               ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.3.                                  ###   
    
         fz=Ao+A1*z+A2*z^2+A3*z^3+A4*z^4
         fwx=(fw-f)/(w-λo)
         fwxx=(fwx-fprime)/(w-λo) 
         fzx=(fz-f)/(z-λo)
         fzxx=(fzx-fprime)/(z-λo)    
         a1=fprime
         a2=(fwxx*(z-λo)-fzxx*(w-λo))/(z-w)   
         a3=(fzxx-fwxx)/(z-w)
         qprimez=a1+2*a2*(z-λo)+3*a3*(z-λo)^2   
         y=z-fz/qprimez   
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.3.              ####################             
                                    ####################
         if isnan(y)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(y)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(y)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.3                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=z                              ##############
         ITNumb=ITNumb+0.50               ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
  ###########################################################
  #                                                       ###
  # THE METHOD PART 1.4.                                  ###   
    
         fy=Ao+A1*y+A2*y^2+A3*y^3+A4*y^4
         fwx=(fw-f)/(w-λo)
         fwxx=(fwx-fprime)/(w-λo) 
         fzx=(fz-f)/(z-λo)
         fzxx=(fzx-fprime)/(z-λo) 
         fyx=(fy-f)/(y-λo)       
         fyxx=(fyx-fprime)/(y-λo) 
         S1=w-λo 
         S2=z-λo
         S3=y-λo    
         b1=fprime
         b2=(fwxx*(-S2*S2*S3+S2*S3*S3)+fzxx*(S1*S1*S3-S1*S3*S3)+fyxx*(-S1*S1*S2+S1*S2*S2))/(-S1*S1*S2+S1*S2*S2+S1*S1*S3-S2*S2*S3-S1*S3*S3+S2*S3*S3)   
         b3=(fwxx*(S2*S2-S3*S3)+fzxx*(-S1*S1+S3*S3)+fyxx*(S1*S1-S2*S2))/(-S1*S1*S2+S1*S2*S2+S1*S1*S3-S2*S2*S3-S1*S3*S3+S2*S3*S3) 
         b4=(fwxx*(-S2+S3)+fzxx*(S1-S3)+fyxx*(-S1+S2))/(-S1*S1*S2+S1*S2*S2+S1*S1*S3-S2*S2*S3-S1*S3*S3+S2*S3*S3)       
         rprimey=b1+2*b2*(y-λo)+3*b3*(y-λo)^2+4*b4*(y-λo)^3   
         l=y-fy/rprimey              
  ###########################################################    
    #                               ####################
    # THE CHECKER 1.4.              ####################             
                                    ####################
         if isnan(l)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(l)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(l)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.4                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=y                              ##############
         ITNumb=ITNumb+0.75               ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=l                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
            end                               ##########
        end                                   ##########
  #                                           ##########
  ######################################################  
  ######################################################              
                
  ######################################################
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################
  ###################################################### 
     ###########################################################
    #                                                       ###
    # THE METHOD PART 1.1.                                  ###   
    
         λo=λo                                              
         f=Ao+A1*λo+A2*λo^2+A3*λo^3+A4*λo^4        
         fprime=A1+2*A2*λo+3*A3*λo^2+4*A4*λo^3     
         u=f/fprime                                
         w=λo-u                                    
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.1.              ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Ao+A1*w+A2*w^2+A3*w^3+A4*w^4
         z=λo-u*((f-fw)/(f-2*fw))                              
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.25               ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.3.                                  ###   
    
         fz=Ao+A1*z+A2*z^2+A3*z^3+A4*z^4
         fwx=(fw-f)/(w-λo)
         fwxx=(fwx-fprime)/(w-λo) 
         fzx=(fz-f)/(z-λo)
         fzxx=(fzx-fprime)/(z-λo)    
         a1=fprime
         a2=(fwxx*(z-λo)-fzxx*(w-λo))/(z-w)   
         a3=(fzxx-fwxx)/(z-w)
         qprimez=a1+2*a2*(z-λo)+3*a3*(z-λo)^2   
         y=z-fz/qprimez   
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.3.              ####################             
                                    ####################
         if isnan(y)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(y)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(y)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.3                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=z                              ##############
         ITNumb=ITNumb+0.50               ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
  ###########################################################
  #                                                       ###
  # THE METHOD PART 1.4.                                  ###   
    
         fy=Ao+A1*y+A2*y^2+A3*y^3+A4*y^4
         fwx=(fw-f)/(w-λo)
         fwxx=(fwx-fprime)/(w-λo) 
         fzx=(fz-f)/(z-λo)
         fzxx=(fzx-fprime)/(z-λo) 
         fyx=(fy-f)/(y-λo)       
         fyxx=(fyx-fprime)/(y-λo) 
         S1=w-λo 
         S2=z-λo
         S3=y-λo    
         b1=fprime
         b2=(fwxx*(-S2*S2*S3+S2*S3*S3)+fzxx*(S1*S1*S3-S1*S3*S3)+fyxx*(-S1*S1*S2+S1*S2*S2))/(-S1*S1*S2+S1*S2*S2+S1*S1*S3-S2*S2*S3-S1*S3*S3+S2*S3*S3)   
         b3=(fwxx*(S2*S2-S3*S3)+fzxx*(-S1*S1+S3*S3)+fyxx*(S1*S1-S2*S2))/(-S1*S1*S2+S1*S2*S2+S1*S1*S3-S2*S2*S3-S1*S3*S3+S2*S3*S3) 
         b4=(fwxx*(-S2+S3)+fzxx*(S1-S3)+fyxx*(-S1+S2))/(-S1*S1*S2+S1*S2*S2+S1*S1*S3-S2*S2*S3-S1*S3*S3+S2*S3*S3)       
         rprimey=b1+2*b2*(y-λo)+3*b3*(y-λo)^2+4*b4*(y-λo)^3   
         l=y-fy/rprimey              
  ###########################################################    
    #                               ####################
    # THE CHECKER 1.4.              ####################             
                                    ####################
         if isnan(l)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(l)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(l)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.4                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=y                              ##############
         ITNumb=ITNumb+0.75               ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=l                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
            end                               ##########
        end                                   ##########
  #                                           ##########
  ###################################################### 
                                              ########## 
            end # If ITNumb>1000 Loop Close   ##########  
        end # While Loop Close                ##########        
  #                                           ##########
  ######################################################  
  ######################################################
 λD=λ   
 ITNumbD=ITNumb
 res=[λD, ITNumbD]
 return(res)
 end
# Out:
# Super16_4P16R (generic function with 1 method)

# %%
"KRAJ. DOle su pomocni algoritmi"
# Out:
# "KRAJ. DOle su pomocni algoritmi"

# %%
D1=Newton_Raphson_Classic(Bo, B1, B2, B3, B4, λoD2, epsd)    
 
#λh,
#EPSD=5*10^-4,
 40.684394 seconds (85.79 M allocations: 3.516 GiB, 1.02% gc time)
#EPSD=5*10^-14,
 40.740012 seconds (85.77 M allocations: 3.515 GiB, 1.02% gc time)
#EPSD=5*10^-16,
 47.463582 seconds (86.69 M allocations: 3.528 GiB, 0.88% gc time)
 
#λwj,
#EPSD=5*10^-4,
 39.577158 seconds (85.77 M allocations: 3.515 GiB, 1.03% gc time)
#EPSD=5*10^-14,
 39.876848 seconds (85.77 M allocations: 3.515 GiB, 1.03% gc time)
#EPSD=5*10^-16,
 47.430246 seconds (86.68 M allocations: 3.528 GiB, 0.89% gc time)
 
#λmd,
#EPSD=5*10^-4,
 39.552891 seconds (85.77 M allocations: 3.515 GiB, 1.06% gc time)
#EPSD=5*10^-14,
 40.241466 seconds (85.77 M allocations: 3.515 GiB, 1.02% gc time)
#EPSD=5*10^-16,
 47.357526 seconds (86.67 M allocations: 3.528 GiB, 0.90% gc time)
# Out:
# UndefVarError: Bo not defined
#
# Stacktrace:
#  [1] top-level scope at In[77]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
D2=Newton_Raphson_WJ_with_RF(μ, Ct, αdr, λoD, epsd)   
 
#λh,
#EPSD=5*10^-4,
 44.170185 seconds (85.77 M allocations: 3.515 GiB, 0.97% gc time)
#EPSD=5*10^-14,
 62.256496 seconds (85.77 M allocations: 3.515 GiB, 0.68% gc time)
#EPSD=5*10^-16,
 64.843149 seconds (85.77 M allocations: 3.515 GiB, 0.65% gc time)
 
#λwj,
#EPSD=5*10^-4,
 41.148758 seconds (85.77 M allocations: 3.515 GiB, 0.99% gc time)
#EPSD=5*10^-14,
 59.708629 seconds (85.77 M allocations: 3.515 GiB, 0.69% gc time)
#EPSD=5*10^-16,
 63.140618 seconds (85.77 M allocations: 3.515 GiB, 0.67% gc time)
 
#λmd,
#EPSD=5*10^-4,
 39.333393 seconds (85.77 M allocations: 3.515 GiB, 1.05% gc time)
#EPSD=5*10^-14,
 56.368570 seconds (85.77 M allocations: 3.515 GiB, 0.75% gc time)
#EPSD=5*10^-16,
 60.541209 seconds (85.77 M allocations: 3.515 GiB, 0.70% gc time)

21442340
# Out:
# UndefVarError: μ not defined
#
# Stacktrace:
#  [1] top-level scope at In[101]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
D3=Newton_Raphson_WJ_without_RF(μ, Ct, αdr, λoD, epsd)   
 
#λh,
#EPSD=5*10^-4,
 39.928796 seconds (85.77 M allocations: 3.515 GiB, 1.06% gc time)
#EPSD=5*10^-14,
 40.926284 seconds (85.77 M allocations: 3.515 GiB, 1.04% gc time)
#EPSD=5*10^-16,
 42.102598 seconds (85.77 M allocations: 3.515 GiB, 1.02% gc time)
 
#λwj,
#EPSD=5*10^-4,
 40.092026 seconds (85.77 M allocations: 3.515 GiB, 1.05% gc time)
#EPSD=5*10^-14,
 40.938882 seconds (85.77 M allocations: 3.515 GiB, 1.04% gc time)
#EPSD=5*10^-16,
 40.764851 seconds (85.77 M allocations: 3.515 GiB, 1.04% gc time)
 
#λmd,
#EPSD=5*10^-4,
 39.431498 seconds (85.77 M allocations: 3.515 GiB, 1.07% gc time)
#EPSD=5*10^-14,
 40.144382 seconds (85.77 M allocations: 3.515 GiB, 1.04% gc time)
#EPSD=5*10^-16,
 40.679866 seconds (85.77 M allocations: 3.515 GiB, 1.04% gc time)

# %%
D4=Super16_4P16R(Bo, B1, B2, B3, B4, λoD, epsd)   
 
#λh,
#EPSD=5*10^-4,
174.400431 seconds (128.20 M allocations: 4.145 GiB, 0.36% gc time)
#EPSD=5*10^-14,
174.534697 seconds (128.33 M allocations: 4.147 GiB, 0.36% gc time)
#EPSD=5*10^-16,
173.930466 seconds (128.33 M allocations: 4.147 GiB, 0.36% gc time)
 
#λwj,
#EPSD=5*10^-4,
174.731504 seconds (128.40 M allocations: 4.149 GiB, 0.36% gc time)
#EPSD=5*10^-14,
174.893425 seconds (128.59 M allocations: 4.152 GiB, 0.36% gc time)
#EPSD=5*10^-16,
174.420206 seconds (128.59 M allocations: 4.152 GiB, 0.36% gc time)
 
#λmd,
#EPSD=5*10^-4,
 92.806539 seconds (87.20 M allocations: 3.356 GiB, 0.51% gc time)
#EPSD=5*10^-14,
127.755953 seconds (98.45 M allocations: 3.524 GiB, 0.40% gc time)
#EPSD=5*10^-16,
127.001809 seconds (98.45 M allocations: 3.524 GiB, 0.41% gc time)

21442340
