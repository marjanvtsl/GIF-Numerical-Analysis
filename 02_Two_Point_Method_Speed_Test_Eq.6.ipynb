# %%
@time begin
    
    v1 =μ1(0.001, 0.001, 0.580) 

end
# Out:
#  42.805760 seconds (80.32 M allocations: 3.377 GiB, 0.96% gc time)
# 21442340

# %%
function μ1(μmin, dμ, μmax)           
counter=0    
for μ=μmin:dμ:μmax
if μ<0.2
   TCmax=0.035
   TCmin=0.0015
elseif μ<0.4
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0015
else
   TCmax=-0.0625*μ+0.0475
   TCmin=0.0125*μ-0.0035
end
        
if μ<0.15
   αdmax=86.667*μ+5
   αdmin=0
elseif μ<0.4
   αdmax=18
   αdmin=0
elseif μ<0.5
   αdmax=-30*μ+30
   αdmin=55.5555555*μ-22.22222222
else  
   αdmax=10
   αdmin=55.5555555*μ-22.22222222     
end      
for Ct=round(TCmin, digits=4):0.0001:round(TCmax, digits=4)
for αd=round(αdmin, digits=1):0.1:round(αdmax, digits=1)
                
counter=counter+1        
μz=(μ*tan(αd*pi/180))#
λh=(sqrt(Ct/2))#
λwj=(λh^2/sqrt((λh+μz)^2+μ^2)+μz)#
λe=(sqrt((sqrt(μ^4+4*λh^4)-μ^2)/2))#
λmd=(λh^2/sqrt((λe+μz)^2+μ^2)+μz)#
##################################################################################################################################              
R=Speed_Test(μ, αd, Ct, λmd, λwj, λe, λh)############################################################################################################
##################################################################################################################################                
         
end
end
end
return(counter)
end
# Out:
# μ1 (generic function with 2 methods)

# %%
function Speed_Test(μ, αd, Ct, λmd, λwj, λe, λh) # αd in degrees #####################  
EPSD=5*10^-16
αdr=αd*pi/180 # αd transform in radians  

λoD=λmd

Bo=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
B1=(-8*μ^3*tan(αdr))
B2=(4*μ^2*(1+(tan(αdr))^2))
B3=(-8*μ*tan(αdr))
B4=(4)
           
Ao=(4*(μ^4)*((tan(αdr))^2)-(Ct^2))
A1=(-8*μ^3*tan(αdr))
A2=(4*μ^2*(1+(tan(αdr))^2))
A3=(-8*μ*tan(αdr))
A4=(4)
   
D1=Ostrowski_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD)    
end
# Out:
# Speed_Test (generic function with 1 method)

# %%
D1=Ostrowski_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD)    
D2=Chun_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD)     
D3=Special_Cordero_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD)     
D4=Jarratt_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD)
# Out:
# UndefVarError: Bo not defined
#
# Stacktrace:
#  [1] top-level scope at In[175]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
function Ostrowski_2P4R(Bo, B1, B2, B3, B4, λo, EPSD)# αd in degrees #####################  

EPS=EPSD  
nano50=0    
nan=0
nan10=0
info50=0    
inf=0
inf10=0
zeroo50=0
zero=0
zero10=0
LoPo=0
ITNumb=0
Jack=0

    
    ####################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λo                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-u                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER 1.1               ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nano50=nano50+1            ####################
         elseif LoPo==2             ####################
         info50=info50+1            ####################
         elseif LoPo==3             ####################
         zeroo50=zeroo50+1          ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         z=w-(fw/fprime)*f/(f-2*fw)    
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan10=nan10+1              ####################
         elseif LoPo==2             ####################
         inf10=inf10+1              ####################
         elseif LoPo==3             ####################
         zero10=zero10+1            ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.5                ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
  #                                           ##########
  ######################################################  
  L1=λ                                        #  #  #  #
  Eps1=Eps                                    #  #  #  #
  ######################################################            
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################
  ######################################################

    ####################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λ                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-u                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER 1.1               ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan=nan+1                  ####################
         elseif LoPo==2             ####################
         inf=inf+1                  ####################
         elseif LoPo==3             ####################
         zero=zero+1                ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         z=w-(fw/fprime)*f/(f-2*fw)     
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan=nan+1                  ####################
         elseif LoPo==2             ####################
         inf=inf+1                  ####################
         elseif LoPo==3             ####################
         zero=zero+1                ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.5                ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
            end # If ITNumb>1000 Loop Close   ##########  
        end # While Loop Close                ##########        
  #                                           ##########
  ######################################################                        
 λD=λ   
 ITNumbD=ITNumb
 res=[λD, ITNumbD]
 return(res)
 end
# Out:
# Ostrowski_2P4R (generic function with 1 method)

# %%
function Chun_2P4R(Bo, B1, B2, B3, B4, λo, EPSD)# αd in degrees #####################  

EPS=EPSD  
nano50=0    
nan=0
nan10=0
info50=0    
inf=0
inf10=0
zeroo50=0
zero=0
zero10=0
LoPo=0
ITNumb=0
Jack=0
    
    ####################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λo                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-u                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER 1.1               ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nano50=nano50+1            ####################
         elseif LoPo==2             ####################
         info50=info50+1            ####################
         elseif LoPo==3             ####################
         zeroo50=zeroo50+1          ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         z=λo-u*(1+fw/f+2*fw^2/f^2) 
        
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan10=nan10+1              ####################
         elseif LoPo==2             ####################
         inf10=inf10+1              ####################
         elseif LoPo==3             ####################
         zero10=zero10+1            ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.5                ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
  #                                           ##########
  ######################################################  
  L1=λ                                        #  #  #  #
  Eps1=Eps                                    #  #  #  #
  ######################################################            
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################

    ####################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λ                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-u                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER 1.1               ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan=nan+1                  ####################
         elseif LoPo==2             ####################
         inf=inf+1                  ####################
         elseif LoPo==3             ####################
         zero=zero+1                ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
                
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         z=λo-u*(1+fw/f+2*fw^2/f^2)     
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan=nan+1                  ####################
         elseif LoPo==2             ####################
         inf=inf+1                  ####################
         elseif LoPo==3             ####################
         zero=zero+1                ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.5                ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
            end # If ITNumb>1000 Loop Close   ##########  
        end # While Loop Close                ##########        
  #                                           ##########
  ######################################################                          
 λD=λ   
 ITNumbD=ITNumb
 res=[λD, ITNumbD]
 return(res)
 end
# Out:
# Chun_2P4R (generic function with 1 method)

# %%
function Special_Cordero_2P4R(Bo, B1, B2, B3, B4, λo, EPSD)# αd in degrees #####################  
# str 55 in Neta, Petkovic...
EPS=EPSD  
nano50=0    
nan=0
nan10=0
info50=0    
inf=0
inf10=0
zeroo50=0
zero=0
zero10=0
LoPo=0
ITNumb=0
Jack=0
    
    ####################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λo                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-u                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER 1.1               ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nano50=nano50+1            ####################
         elseif LoPo==2             ####################
         info50=info50+1            ####################
         elseif LoPo==3             ####################
         zeroo50=zeroo50+1          ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         z=w-(fw/fprime)*(1+2*fw/f)  
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan10=nan10+1              ####################
         elseif LoPo==2             ####################
         inf10=inf10+1              ####################
         elseif LoPo==3             ####################
         zero10=zero10+1            ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.5                ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
  #                                           ##########
  ######################################################  
  ######################################################            
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################
  ######################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λ                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-u                                      
    #                                                ###
    ####################################################
    #                               ####################
    # THE CHECKER 1.1               ####################             
                                    ####################
         if isnan(w)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(w)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(w)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan=nan+1                  ####################
         elseif LoPo==2             ####################
         inf=inf+1                  ####################
         elseif LoPo==3             ####################
         zero=zero+1                ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.1                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=λo                             ##############
         ITNumb=ITNumb+0                  ##############
         eps=0                            ##############
         Eps=0                            ##############
            else                          ##############  
                                          ##############
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         z=w-(fw/fprime)*(1+2*fw/f)   
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE CHECKER 1.2.              ####################             
                                    ####################
         if isnan(z)==true          ####################
         LoPo=LoPo+1                ####################
         elseif isinf(z)==true      ####################
         LoPo=LoPo+2                ####################
         elseif iszero(z)==true     ####################
         LoPo=LoPo+3                ####################
         else                       ####################
         LoPo=0                     ####################
         end                        ####################
                                    ####################      
         if LoPo==1                 ####################
         nan=nan+1                  ####################
         elseif LoPo==2             ####################
         inf=inf+1                  ####################
         elseif LoPo==3             ####################
         zero=zero+1                ####################
                        end         ####################
  #                                 ####################
  ######################################################
  #                                       ##############
  # THE DISTRIBUTER 1.2                   ##############
  #                                       ##############
            if LoPo >0                    ##############
         λ=w                              ##############
         ITNumb=ITNumb+0.5                ##############
         eps=0                            ##############
         Eps=abs((λ-λo)/λ)                ##############
            else                          ##############  
                                          ##############
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                end                           ##########
            end                               ##########
            end # If ITNumb>1000 Loop Close   ##########  
        end # While Loop Close                ##########        
  #                                           ##########
  #######################################################                     
 
 λD=λ   
 ITNumbD=ITNumb
 res=[λD, ITNumbD]
 return(res)
 end
# Out:
# Special_Cordero_2P4R (generic function with 1 method)

# %%
function Jarratt_2P4R(Bo, B1, B2, B3, B4, λo, EPSD)# αd in degrees #####################  
# (1.63 in Dzunic PhD )#  teta = 3/2.## THE MOST CITED AND THE MOST SIMPLIEST
EPS=EPSD  
ITNumb=0
Jack=0
    
    ####################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λo                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-(2/3)*u                                      
    #                                                ###
    ####################################################
   
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
    
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         fwprime=B1+2*B2*w+3*B3*w^2+4*B4*w^3
         z=λo-u*(3*fwprime+fprime)/(6*fwprime-2*fprime)
    #                                                       ###
    ###########################################################    
    #                               ####################
    # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                
  ######################################################            
  #                       ##############################
  # THE LOOP OPENER       ##############################   
  #                       ##############################
        while eps>EPS     ##############################      
        if ITNumb>1000    ##############################
           eps=0          ##############################
           Jack=Jack+1    ############################## 
       else               ##############################
  ######################################################
    #                                                ###
    # THE METHOD PART 1.1                            ###     
         
         λo=λ                                       
         f=Bo+B1*λo+B2*λo^2+B3*λo^3+B4*λo^4          
         fprime=B1+2*B2*λo+3*B3*λo^2+4*B4*λo^3
         u=f/fprime                               
         w=λo-(2/3)*u                                      
    #                                                ###
    ####################################################
   
    ###########################################################
    #                                                       ###
    # THE METHOD PART 1.2.                                  ###   
         fw=Bo+B1*w+B2*w^2+B3*w^3+B4*w^4
         fwprime=B1+2*B2*w+3*B3*w^2+4*B4*w^3
         z=λo-u*(3*fwprime+fprime)/(6*fwprime-2*fprime)  
    #                                                       ###
    ###########################################################    
    #                               ####################
  
 #######################################################
 # THE ITERATION FINISHER                     ##########
 #                                            ##########     
             λ=z                              ##########
             ITNumb=ITNumb+1                  ##########
             eps=abs((λ-λo)/λ)                ##########
             Eps=eps                          ##########
                                               ##########
            end # If ITNumb>1000 Loop Close   ##########  
        end # While Loop Close                ##########        
  #                                           ##########
  ######################################################  
  # #                               ####################
  ######################################################                          

 λD=λ   
 ITNumbD=ITNumb
 res=[λD,ITNumbD]
 return(res)
 end
# Out:
# Jarratt_2P4R (generic function with 1 method)

# %%
"KRAJ. DOle su pomocni algoritmi"
# Out:
# "KRAJ. DOle su pomocni algoritmi"

# %%
#21442340
#D1=Ostrowski_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD)    

 #λh,
 #EPSD=5*10^-4,
 41.922631 seconds (85.77 M allocations: 3.515 GiB, 1.06% gc time)
 41.957711 seconds (85.77 M allocations: 3.515 GiB, 1.03% gc time)
 41.821654 seconds (85.77 M allocations: 3.515 GiB, 1.03% gc time)
 #EPSD=5*10^-14,
 40.368654 seconds (81.48 M allocations: 3.408 GiB, 1.05% gc time)
 40.015067 seconds (81.48 M allocations: 3.408 GiB, 1.03% gc time)
 40.371375 seconds (81.48 M allocations: 3.408 GiB, 1.04% gc time)
 #EPSD=5*10^-16,
 46.122761 seconds (80.82 M allocations: 3.388 GiB, 0.91% gc time)
 46.549410 seconds (80.82 M allocations: 3.388 GiB, 0.91% gc time)
 46.001629 seconds (80.82 M allocations: 3.388 GiB, 0.92% gc time)

 #λwj,
 #EPSD=5*10^-4,
 41.160611 seconds (85.77 M allocations: 3.515 GiB, 1.05% gc time)
 40.902247 seconds (85.77 M allocations: 3.515 GiB, 1.05% gc time)
 41.199740 seconds (85.77 M allocations: 3.515 GiB, 1.04% gc time)
 #EPSD=5*10^-14,
 39.930498 seconds (81.60 M allocations: 3.411 GiB, 1.06% gc time)
 39.939973 seconds (81.60 M allocations: 3.411 GiB, 1.06% gc time)
 39.802263 seconds (81.60 M allocations: 3.411 GiB, 1.04% gc time)
 #EPSD=5*10^-16,
 43.840594 seconds (81.42 M allocations: 3.404 GiB, 0.95% gc time)
 44.223229 seconds (81.42 M allocations: 3.404 GiB, 0.96% gc time)
 44.245221 seconds (81.42 M allocations: 3.404 GiB, 0.95% gc time)

 #λmd,
 #EPSD=5*10^-4,
 41.067845 seconds (85.75 M allocations: 3.514 GiB, 1.06% gc time)
 41.188092 seconds (85.75 M allocations: 3.514 GiB, 1.07% gc time)
 41.183139 seconds (85.75 M allocations: 3.514 GiB, 1.07% gc time)
 #EPSD=5*10^-14,
 39.036675 seconds (80.93 M allocations: 3.394 GiB, 1.09% gc time)
 39.164714 seconds (80.93 M allocations: 3.394 GiB, 1.08% gc time)
 38.975893 seconds (80.93 M allocations: 3.394 GiB, 1.07% gc time)
 #EPSD=5*10^-16,
 42.922556 seconds (80.32 M allocations: 3.377 GiB, 0.96% gc time)
 43.339049 seconds (80.32 M allocations: 3.377 GiB, 0.96% gc time)

# %%
#21442340
#D2=Chun_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD) 

 #λh,
 #EPSD=5*10^-4,
 42.701345 seconds (85.77 M allocations: 3.515 GiB, 1.00% gc time)
 42.732379 seconds (85.77 M allocations: 3.515 GiB, 0.99% gc time)
 42.659194 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 #EPSD=5*10^-14,
 41.170982 seconds (81.73 M allocations: 3.414 GiB, 0.99% gc time)
 41.658960 seconds (81.73 M allocations: 3.414 GiB, 1.00% gc time)
 41.263694 seconds (81.73 M allocations: 3.414 GiB, 1.00% gc time)
 #EPSD=5*10^-16,
 136.109462 seconds (85.72 M allocations: 3.460 GiB, 0.32% gc time)
 136.649726 seconds (85.72 M allocations: 3.460 GiB, 0.33% gc time)
 135.833841 seconds (85.72 M allocations: 3.460 GiB, 0.33% gc time)

########################################
 #λwj,
 #EPSD=5*10^-4,
 41.647679 seconds (85.77 M allocations: 3.515 GiB, 1.02% gc time)
 42.008833 seconds (85.77 M allocations: 3.515 GiB, 1.03% gc time)
 41.929455 seconds (85.77 M allocations: 3.515 GiB, 1.04% gc time)
 #EPSD=5*10^-14,
 40.576487 seconds (81.60 M allocations: 3.411 GiB, 1.00% gc time)
 40.038146 seconds (81.64 M allocations: 3.412 GiB, 1.04% gc time)
 40.617792 seconds (81.64 M allocations: 3.412 GiB, 1.02% gc time)
 #EPSD=5*10^-16,
 144.391751 seconds (85.54 M allocations: 3.450 GiB, 0.31% gc time)
 145.364714 seconds (85.54 M allocations: 3.450 GiB, 0.30% gc time)
 145.311040 seconds (85.54 M allocations: 3.450 GiB, 0.31% gc time)

 #λmd,
 #EPSD=5*10^-4,
 40.753343 seconds (85.75 M allocations: 3.514 GiB, 1.03% gc time)
 41.041768 seconds (85.75 M allocations: 3.514 GiB, 1.05% gc time)
 41.036912 seconds (85.75 M allocations: 3.514 GiB, 1.05% gc time)
 #EPSD=5*10^-14,
 38.772710 seconds (81.29 M allocations: 3.403 GiB, 1.04% gc time)
 39.335719 seconds (81.29 M allocations: 3.403 GiB, 1.06% gc time)
 38.910041 seconds (81.29 M allocations: 3.403 GiB, 1.04% gc time)
 #EPSD=5*10^-16,
 144.286516 seconds (85.64 M allocations: 3.453 GiB, 0.31% gc time)
 141.743250 seconds (85.64 M allocations: 3.453 GiB, 0.31% gc time)
 142.145897 seconds (85.64 M allocations: 3.453 GiB, 0.31% gc time)

# %%
#21442340
#D3=Special_Cordero_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD) 

 #λh,
 #EPSD=5*10^-4,
 42.359614 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 42.343217 seconds (85.77 M allocations: 3.515 GiB, 0.99% gc time)
 42.429241 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 #EPSD=5*10^-14,
 40.697907 seconds (81.55 M allocations: 3.410 GiB, 0.97% gc time)
 41.359732 seconds (81.55 M allocations: 3.410 GiB, 0.97% gc time)
 41.649320 seconds (81.55 M allocations: 3.410 GiB, 0.98% gc time)
 #EPSD=5*10^-16,
 134.110642 seconds (85.76 M allocations: 3.459 GiB, 0.32% gc time)
 133.954106 seconds (85.76 M allocations: 3.459 GiB, 0.31% gc time)
 133.037024 seconds (85.76 M allocations: 3.459 GiB, 0.32% gc time)

########################################
 #λwj,
 #EPSD=5*10^-4,
 41.553903 seconds (85.77 M allocations: 3.515 GiB, 0.99% gc time)
 41.573470 seconds (85.77 M allocations: 3.515 GiB, 0.97% gc time)
 41.409692 seconds (85.77 M allocations: 3.515 GiB, 0.97% gc time)
 #EPSD=5*10^-14,
 40.576487 seconds (81.60 M allocations: 3.411 GiB, 1.00% gc time)
 39.797553 seconds (81.60 M allocations: 3.411 GiB, 0.99% gc time)
 39.741565 seconds (81.60 M allocations: 3.411 GiB, 0.99% gc time)
 #EPSD=5*10^-16,
 139.357125 seconds (85.72 M allocations: 3.453 GiB, 0.31% gc time)
 138.555298 seconds (85.72 M allocations: 3.453 GiB, 0.31% gc time)
 138.897413 seconds (85.72 M allocations: 3.453 GiB, 0.31% gc time)

 #λmd,
 #EPSD=5*10^-4,
 40.734473 seconds (85.75 M allocations: 3.514 GiB, 1.00% gc time)
 41.189658 seconds (85.75 M allocations: 3.514 GiB, 1.02% gc time)
 41.225829 seconds (85.75 M allocations: 3.514 GiB, 1.02% gc time)
 #EPSD=5*10^-14,
 39.006356 seconds (80.99 M allocations: 3.396 GiB, 1.03% gc time)
 39.022771 seconds (80.99 M allocations: 3.396 GiB, 1.03% gc time)
 38.493822 seconds (80.99 M allocations: 3.396 GiB, 1.03% gc time)
 #EPSD=5*10^-16,
 136.592162 seconds (85.52 M allocations: 3.449 GiB, 0.31% gc time)
 137.650278 seconds (85.52 M allocations: 3.449 GiB, 0.32% gc time)
 139.477742 seconds (85.52 M allocations: 3.449 GiB, 0.31% gc time)

# %%
#21442340
#D4=Jarratt_2P4R(Bo, B1, B2, B3, B4, λoD, EPSD)   

 #λh,
 #EPSD=5*10^-4,
 43.219975 seconds (85.77 M allocations: 3.515 GiB, 0.97% gc time)
 43.267162 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 43.565502 seconds (85.77 M allocations: 3.515 GiB, 0.97% gc time)
 #EPSD=5*10^-14,
 44.073764 seconds (85.77 M allocations: 3.515 GiB, 0.95% gc time)
 44.636057 seconds (85.77 M allocations: 3.515 GiB, 0.95% gc time)
 44.271269 seconds (85.77 M allocations: 3.515 GiB, 0.95% gc time)
 #EPSD=5*10^-16,
 58.273555 seconds (86.70 M allocations: 3.528 GiB, 0.74% gc time)
 58.867873 seconds (86.70 M allocations: 3.528 GiB, 0.73% gc time)
 57.373163 seconds (86.70 M allocations: 3.528 GiB, 0.73% gc time)

 #λwj,
 #EPSD=5*10^-4,
 42.553367 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 42.600428 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 42.561267 seconds (85.77 M allocations: 3.515 GiB, 0.97% gc time)
 #EPSD=5*10^-14,
 43.763875 seconds (85.77 M allocations: 3.515 GiB, 0.95% gc time)
 43.418133 seconds (85.77 M allocations: 3.515 GiB, 0.95% gc time)
 43.535741 seconds (85.77 M allocations: 3.515 GiB, 0.95% gc time)
 #EPSD=5*10^-16,
 57.150232 seconds (86.67 M allocations: 3.528 GiB, 0.74% gc time) 
 57.344578 seconds (86.67 M allocations: 3.528 GiB, 0.74% gc time)
 56.645042 seconds (86.67 M allocations: 3.528 GiB, 0.73% gc time)

 #λmd,
 #EPSD=5*10^-4,
 42.522913 seconds (85.77 M allocations: 3.515 GiB, 0.97% gc time)
 42.614635 seconds (85.77 M allocations: 3.515 GiB, 0.99% gc time)
 42.484248 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 #EPSD=5*10^-14,
 42.748822 seconds (85.77 M allocations: 3.515 GiB, 0.98% gc time)
 42.784989 seconds (85.77 M allocations: 3.515 GiB, 0.96% gc time)
 43.127577 seconds (85.77 M allocations: 3.515 GiB, 0.95% gc time)
 #EPSD=5*10^-16,
 56.932870 seconds (86.67 M allocations: 3.528 GiB, 0.74% gc time)
 56.827253 seconds (86.67 M allocations: 3.528 GiB, 0.74% gc time)
 57.219604 seconds (86.67 M allocations: 3.528 GiB, 0.74% gc time)
# Out:
# syntax: extra token "seconds" after end of expression
#
# Stacktrace:
#  [1] top-level scope at In[88]:6
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
